# %%
import os
import shutil
import xml.etree.ElementTree as ET
import numpy as np
import cv2
from PIL import Image

def parse_inkml(file_path):
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()
        traces = {}
        for trace in root.findall('{http://www.w3.org/2003/InkML}trace'):
            trace_id = str(trace.attrib['id'])
            coords = []
            for point in trace.text.strip().split(','):
                if point.strip() == '':
                    continue
                parts = point.strip().split()
                if len(parts) >= 2:
                    x = float(parts[0])
                    y = float(parts[1])
                    coords.append((x, y))
            traces[trace_id] = coords

        trace_groups = []
        for traceView in root.findall('.//{http://www.w3.org/2003/InkML}traceView'):
            trace_groups.append(traceView.attrib['traceDataRef'])

        return traces, trace_groups
    except Exception as e:
        print(f"Error parsing {file_path}: {e}")
        return None, None

def normalize_and_render(traces, trace_groups=None, img_size=256, padding=10):
    all_points = []
    keys = trace_groups if trace_groups else traces.keys()

    for t_id in keys:
        if t_id in traces:
            all_points.extend(traces[t_id])
    
    if not all_points:
        raise ValueError("No valid stroke points found.")

    all_points = np.array(all_points)
    min_x, min_y = np.min(all_points, axis=0)
    max_x, max_y = np.max(all_points, axis=0)

    scale = (img_size - 2 * padding) / max(max_x - min_x, max_y - min_y + 1e-6)
    canvas = np.ones((img_size, img_size), dtype=np.uint8) * 255

    for t_id in keys:
        if t_id in traces:
            trace = np.array(traces[t_id])
            trace -= [min_x, min_y]
            trace *= scale
            trace += padding
            trace = trace.astype(np.int32)

            for i in range(1, len(trace)):
                pt1 = tuple(trace[i - 1])
                pt2 = tuple(trace[i])
                cv2.line(canvas, pt1, pt2, color=0, thickness=2)

    return canvas

def process_inkml_folder(inkml_root_dir, user_output_dir):
    output_img_dir = os.path.join(user_output_dir, "processed_images")

    # Recreate the output directory
    if os.path.exists(user_output_dir):
        shutil.rmtree(user_output_dir)
    os.makedirs(output_img_dir, exist_ok=True)

    for root, _, files in os.walk(inkml_root_dir):
        for file in files:
            if file.endswith('.inkml'):
                file_path = os.path.join(root, file)
                traces, trace_groups = parse_inkml(file_path)
                if traces:
                    img = normalize_and_render(traces, trace_groups)
                    base_name = os.path.splitext(file)[0]
                    img_path = os.path.join(output_img_dir, f"{base_name}.png")
                    Image.fromarray(img).save(img_path)
                    print(f"Processed: {file}")

# Run the conversion
inkml_dir = '/kaggle/input/crohme2019/crohme2019/crohme2019/valid'
user_output_dir = 'results_valid'
process_inkml_folder(inkml_dir, user_output_dir)

print(f"\n✅ Done! Processed images saved in: {user_output_dir}/processed_images")
# Out:
# Processed: RIT_2014_124.inkml
# Processed: 507_em_76.inkml
# Processed: RIT_2014_33.inkml
# Processed: 37_em_2.inkml
# Processed: 501_em_23.inkml
# Processed: 509_em_95.inkml
# Processed: 501_em_22.inkml
# Processed: RIT_2014_261.inkml
# Processed: 511_em_262.inkml
# Processed: RIT_2014_187.inkml
# Processed: RIT_2014_258.inkml
# Processed: 518_em_434.inkml
# Processed: 511_em_265.inkml
# Processed: RIT_2014_163.inkml
# Processed: RIT_2014_91.inkml
# Processed: RIT_2014_286.inkml
# Processed: 519_em_451.inkml
# Processed: 514_em_348.inkml
# Processed: 512_em_276.inkml
# Processed: 31_em_197.inkml
# Processed: 26_em_97.inkml
# Processed: 513_em_321.inkml
# Processed: RIT_2014_247.inkml
# Processed: 37_em_30.inkml
# Processed: 514_em_326.inkml
# Processed: 510_em_105.inkml
# Processed: 37_em_14.inkml
# Processed: RIT_2014_107.inkml
# Processed: 31_em_185.inkml
# Processed: 517_em_406.inkml
# Processed: 507_em_73.inkml
# Processed: RIT_2014_127.inkml
# Processed: 502_em_16.inkml
# Processed: 32_em_213.inkml
# Processed: 36_em_29.inkml
# Processed: 515_em_351.inkml
# Processed: RIT_2014_303.inkml
# Processed: RIT_2014_69.inkml
# Processed: RIT_2014_161.inkml
# Processed: 28_em_143.inkml
# Processed: 34_em_247.inkml
# Processed: RIT_2014_249.inkml
# Processed: 26_em_77.inkml
# Processed: 516_em_383.inkml
# Processed: 518_em_424.inkml
# Processed: 505_em_54.inkml
# Processed: 512_em_296.inkml
# Processed: 26_em_94.inkml
# Processed: 37_em_0.inkml
# Processed: 29_em_165.inkml
# Processed: RIT_2014_156.inkml
# Processed: 26_em_96.inkml
# Processed: RIT_2014_36.inkml
# Processed: 513_em_300.inkml
# Processed: 509_em_99.inkml
# Processed: RIT_2014_206.inkml
# Processed: RIT_2014_96.inkml
# Processed: RIT_2014_55.inkml
# Processed: 515_em_355.inkml
# Processed: 26_em_95.inkml
# Processed: RIT_2014_162.inkml
# Processed: RIT_2014_178.inkml
# Processed: RIT_2014_235.inkml
# Processed: 518_em_416.inkml
# Processed: 519_em_442.inkml
# Processed: 31_em_196.inkml
# Processed: 32_em_210.inkml
# Processed: RIT_2014_82.inkml
# Processed: 29_em_158.inkml
# Processed: RIT_2014_131.inkml
# Processed: 34_em_241.inkml
# Processed: 27_em_124.inkml
# Processed: 516_em_396.inkml
# Processed: 509_em_91.inkml
# Processed: 519_em_452.inkml
# Processed: 502_em_2.inkml
# Processed: RIT_2014_68.inkml
# Processed: RIT_2014_12.inkml
# Processed: 34_em_239.inkml
# Processed: RIT_2014_7.inkml
# Processed: 517_em_413.inkml
# Processed: 32_em_215.inkml
# Processed: 500_em_108.inkml
# Processed: RIT_2014_279.inkml
# Processed: 28_em_141.inkml
# Processed: 35_em_14.inkml
# Processed: RIT_2014_291.inkml
# Processed: 34_em_237.inkml
# Processed: 23_em_51.inkml
# Processed: 508_em_82.inkml
# Processed: 35_em_12.inkml
# Processed: RIT_2014_42.inkml
# Processed: RIT_2014_221.inkml
# Processed: RIT_2014_94.inkml
# Processed: 36_em_41.inkml
# Processed: 36_em_43.inkml
# Processed: RIT_2014_166.inkml
# Processed: 28_em_127.inkml
# Processed: RIT_2014_106.inkml
# Processed: RIT_2014_244.inkml
# Processed: 35_em_16.inkml
# Processed: 31_em_184.inkml
# Processed: 26_em_84.inkml
# Processed: RIT_2014_180.inkml
# Processed: 517_em_407.inkml
# Processed: 511_em_267.inkml
# Processed: 34_em_245.inkml
# Processed: RIT_2014_93.inkml
# Processed: 31_em_177.inkml
# Processed: RIT_2014_118.inkml
# Processed: 504_em_46.inkml
# Processed: 512_em_298.inkml
# Processed: 502_em_15.inkml
# Processed: RIT_2014_116.inkml
# Processed: RIT_2014_200.inkml
# Processed: 507_em_68.inkml
# Processed: 505_em_51.inkml
# Processed: 502_em_11.inkml
# Processed: 508_em_79.inkml
# Processed: RIT_2014_139.inkml
# Processed: 34_em_242.inkml
# Processed: 514_em_340.inkml
# Processed: 28_em_149.inkml
# Processed: 514_em_347.inkml
# Processed: RIT_2014_260.inkml
# Processed: 20_em_26.inkml
# Processed: RIT_2014_143.inkml
# Processed: RIT_2014_134.inkml
# Processed: RIT_2014_78.inkml
# Processed: 29_em_167.inkml
# Processed: RIT_2014_120.inkml
# Processed: 502_em_14.inkml
# Processed: RIT_2014_150.inkml
# Processed: 27_em_100.inkml
# Processed: 501_em_17.inkml
# Processed: 26_em_90.inkml
# Processed: 514_em_330.inkml
# Processed: 510_em_106.inkml
# Processed: 37_em_12.inkml
# Processed: 23_em_69.inkml
# Processed: RIT_2014_263.inkml
# Processed: 27_em_107.inkml
# Processed: 509_em_89.inkml
# Processed: RIT_2014_164.inkml
# Processed: 519_em_459.inkml
# Processed: RIT_2014_85.inkml
# Processed: 23_em_70.inkml
# Processed: 507_em_72.inkml
# Processed: 502_em_20.inkml
# Processed: 501_em_20.inkml
# Processed: 35_em_20.inkml
# Processed: 28_em_142.inkml
# Processed: 37_em_22.inkml
# Processed: 27_em_102.inkml
# Processed: RIT_2014_54.inkml
# Processed: 501_em_8.inkml
# Processed: 36_em_27.inkml
# Processed: RIT_2014_192.inkml
# Processed: 18_em_18.inkml
# Processed: RIT_2014_288.inkml
# Processed: 31_em_178.inkml
# Processed: 37_em_29.inkml
# Processed: 36_em_45.inkml
# Processed: 502_em_13.inkml
# Processed: RIT_2014_168.inkml
# Processed: RIT_2014_229.inkml
# Processed: 34_em_228.inkml
# Processed: RIT_2014_65.inkml
# Processed: 519_em_456.inkml
# Processed: 20_em_40.inkml
# Processed: RIT_2014_41.inkml
# Processed: 29_em_169.inkml
# Processed: 515_em_353.inkml
# Processed: RIT_2014_87.inkml
# Processed: RIT_2014_99.inkml
# Processed: 18_em_13.inkml
# Processed: 34_em_244.inkml
# Processed: 27_em_109.inkml
# Processed: 514_em_328.inkml
# Processed: 34_em_233.inkml
# Processed: 519_em_458.inkml
# Processed: RIT_2014_21.inkml
# Processed: 29_em_151.inkml
# Processed: 20_em_33.inkml
# Processed: 20_em_46.inkml
# Processed: RIT_2014_109.inkml
# Processed: 519_em_443.inkml
# Processed: 27_em_106.inkml
# Processed: 26_em_88.inkml
# Processed: 501_em_6.inkml
# Processed: RIT_2014_157.inkml
# Processed: RIT_2014_240.inkml
# Processed: 31_em_187.inkml
# Processed: 517_em_410.inkml
# Processed: 36_em_42.inkml
# Processed: 29_em_154.inkml
# Processed: 37_em_21.inkml
# Processed: 518_em_422.inkml
# Processed: 505_em_52.inkml
# Processed: 37_em_9.inkml
# Processed: 512_em_285.inkml
# Processed: 27_em_115.inkml
# Processed: 512_em_280.inkml
# Processed: 35_em_2.inkml
# Processed: 20_em_36.inkml
# Processed: RIT_2014_241.inkml
# Processed: 518_em_433.inkml
# Processed: RIT_2014_84.inkml
# Processed: RIT_2014_114.inkml
# Processed: 511_em_268.inkml
# Processed: 37_em_20.inkml
# Processed: 26_em_86.inkml
# Processed: 508_em_83.inkml
# Processed: 23_em_60.inkml
# Processed: RIT_2014_294.inkml
# Processed: 32_em_218.inkml
# Processed: 515_em_369.inkml
# Processed: 34_em_231.inkml
# Processed: 34_em_248.inkml
# Processed: 35_em_5.inkml
# Processed: 517_em_409.inkml
# Processed: RIT_2014_98.inkml
# Processed: RIT_2014_245.inkml
# Processed: RIT_2014_212.inkml
# Processed: RIT_2014_292.inkml
# Processed: 519_em_444.inkml
# Processed: 519_em_445.inkml
# Processed: 512_em_288.inkml
# Processed: 28_em_125.inkml
# Processed: 18_em_5.inkml
# Processed: RIT_2014_18.inkml
# Processed: 512_em_275.inkml
# Processed: 18_em_11.inkml
# Processed: 518_em_418.inkml
# Processed: 511_em_252.inkml
# Processed: 18_em_3.inkml
# Processed: RIT_2014_83.inkml
# Processed: 37_em_8.inkml
# Processed: 511_em_251.inkml
# Processed: 26_em_76.inkml
# Processed: 516_em_380.inkml
# Processed: 23_em_56.inkml
# Processed: 505_em_47.inkml
# Processed: 516_em_397.inkml
# Processed: 514_em_336.inkml
# Processed: 23_em_61.inkml
# Processed: 18_em_4.inkml
# Processed: 504_em_42.inkml
# Processed: 503_em_34.inkml
# Processed: 26_em_81.inkml
# Processed: 516_em_394.inkml
# Processed: 32_em_217.inkml
# Processed: 514_em_335.inkml
# Processed: 512_em_293.inkml
# Processed: 34_em_230.inkml
# Processed: RIT_2014_35.inkml
# Processed: 515_em_370.inkml
# Processed: RIT_2014_185.inkml
# Processed: RIT_2014_194.inkml
# Processed: RIT_2014_140.inkml
# Processed: RIT_2014_283.inkml
# Processed: 31_em_190.inkml
# Processed: 505_em_50.inkml
# Processed: 34_em_226.inkml
# Processed: 23_em_66.inkml
# Processed: RIT_2014_215.inkml
# Processed: 37_em_3.inkml
# Processed: RIT_2014_148.inkml
# Processed: RIT_2014_119.inkml
# Processed: 513_em_301.inkml
# Processed: RIT_2014_265.inkml
# Processed: RIT_2014_58.inkml
# Processed: 518_em_429.inkml
# Processed: 506_em_59.inkml
# Processed: RIT_2014_172.inkml
# Processed: 501_em_1.inkml
# Processed: 517_em_411.inkml
# Processed: 29_em_174.inkml
# Processed: 20_em_38.inkml
# Processed: 26_em_93.inkml
# Processed: 520_em_464.inkml
# Processed: 517_em_402.inkml
# Processed: RIT_2014_307.inkml
# Processed: 514_em_346.inkml
# Processed: 23_em_54.inkml
# Processed: 31_em_183.inkml
# Processed: 510_em_102.inkml
# Processed: RIT_2014_26.inkml
# Processed: RIT_2014_186.inkml
# Processed: 519_em_450.inkml
# Processed: 37_em_15.inkml
# Processed: 29_em_152.inkml
# Processed: RIT_2014_4.inkml
# Processed: 20_em_30.inkml
# Processed: 502_em_4.inkml
# Processed: RIT_2014_242.inkml
# Processed: 27_em_108.inkml
# Processed: 35_em_19.inkml
# Processed: RIT_2014_173.inkml
# Processed: RIT_2014_66.inkml
# Processed: RIT_2014_177.inkml
# Processed: 18_em_14.inkml
# Processed: 503_em_31.inkml
# Processed: RIT_2014_222.inkml
# Processed: 515_em_356.inkml
# Processed: 32_em_201.inkml
# Processed: 18_em_12.inkml
# Processed: RIT_2014_105.inkml
# Processed: 35_em_21.inkml
# Processed: 26_em_91.inkml
# Processed: 34_em_225.inkml
# Processed: 501_em_18.inkml
# Processed: RIT_2014_151.inkml
# Processed: 35_em_13.inkml
# Processed: 28_em_132.inkml
# Processed: 514_em_337.inkml
# Processed: 32_em_221.inkml
# Processed: 503_em_30.inkml
# Processed: 32_em_200.inkml
# Processed: 28_em_131.inkml
# Processed: 28_em_147.inkml
# Processed: 26_em_83.inkml
# Processed: 26_em_99.inkml
# Processed: RIT_2014_128.inkml
# Processed: RIT_2014_136.inkml
# Processed: 20_em_28.inkml
# Processed: 23_em_58.inkml
# Processed: 515_em_350.inkml
# Processed: 512_em_297.inkml
# Processed: 507_em_69.inkml
# Processed: 516_em_378.inkml
# Processed: 516_em_395.inkml
# Processed: RIT_2014_191.inkml
# Processed: 37_em_28.inkml
# Processed: 519_em_463.inkml
# Processed: 29_em_171.inkml
# Processed: 514_em_331.inkml
# Processed: 37_em_26.inkml
# Processed: RIT_2014_280.inkml
# Processed: 517_em_400.inkml
# Processed: 35_em_1.inkml
# Processed: RIT_2014_219.inkml
# Processed: 20_em_29.inkml
# Processed: RIT_2014_259.inkml
# Processed: RIT_2014_202.inkml
# Processed: 506_em_65.inkml
# Processed: 515_em_371.inkml
# Processed: RIT_2014_232.inkml
# Processed: 20_em_44.inkml
# Processed: 37_em_6.inkml
# Processed: RIT_2014_297.inkml
# Processed: RIT_2014_208.inkml
# Processed: 23_em_68.inkml
# Processed: 35_em_6.inkml
# Processed: RIT_2014_19.inkml
# Processed: 37_em_19.inkml
# Processed: 509_em_93.inkml
# Processed: RIT_2014_298.inkml
# Processed: 505_em_48.inkml
# Processed: RIT_2014_138.inkml
# Processed: 28_em_134.inkml
# Processed: RIT_2014_255.inkml
# Processed: RIT_2014_52.inkml
# Processed: 35_em_8.inkml
# Processed: 28_em_148.inkml
# Processed: 20_em_42.inkml
# Processed: 502_em_6.inkml
# Processed: RIT_2014_248.inkml
# Processed: 23_em_64.inkml
# Processed: 509_em_94.inkml
# Processed: 36_em_36.inkml
# Processed: 18_em_20.inkml
# Processed: 31_em_189.inkml
# Processed: 519_em_439.inkml
# Processed: RIT_2014_272.inkml
# Processed: RIT_2014_311.inkml
# Processed: 518_em_423.inkml
# Processed: RIT_2014_62.inkml
# Processed: 32_em_207.inkml
# Processed: RIT_2014_198.inkml
# Processed: 18_em_23.inkml
# Processed: 37_em_11.inkml
# Processed: RIT_2014_167.inkml
# Processed: RIT_2014_37.inkml
# Processed: 507_em_70.inkml
# Processed: 34_em_236.inkml
# Processed: 504_em_37.inkml
# Processed: 501_em_16.inkml
# Processed: 514_em_329.inkml
# Processed: 32_em_205.inkml
# Processed: RIT_2014_111.inkml
# Processed: 18_em_8.inkml
# Processed: RIT_2014_2.inkml
# Processed: 20_em_34.inkml
# Processed: 516_em_390.inkml
# Processed: 23_em_73.inkml
# Processed: 36_em_40.inkml
# Processed: 510_em_100.inkml
# Processed: 514_em_339.inkml
# Processed: 513_em_322.inkml
# Processed: 512_em_289.inkml
# Processed: 27_em_101.inkml
# Processed: RIT_2014_295.inkml
# Processed: 35_em_10.inkml
# Processed: 507_em_75.inkml
# Processed: RIT_2014_74.inkml
# Processed: RIT_2014_228.inkml
# Processed: 35_em_22.inkml
# Processed: 510_em_104.inkml
# Processed: RIT_2014_113.inkml
# Processed: 36_em_49.inkml
# Processed: 520_em_467.inkml
# Processed: 20_em_35.inkml
# Processed: RIT_2014_170.inkml
# Processed: 509_em_90.inkml
# Processed: 31_em_193.inkml
# Processed: 32_em_212.inkml
# Processed: RIT_2014_299.inkml
# Processed: RIT_2014_47.inkml
# Processed: 513_em_312.inkml
# Processed: RIT_2014_254.inkml
# Processed: RIT_2014_266.inkml
# Processed: 31_em_192.inkml
# Processed: 515_em_366.inkml
# Processed: RIT_2014_310.inkml
# Processed: 29_em_159.inkml
# Processed: RIT_2014_89.inkml
# Processed: 515_em_361.inkml
# Processed: RIT_2014_171.inkml
# Processed: RIT_2014_73.inkml
# Processed: 502_em_24.inkml
# Processed: 515_em_359.inkml
# Processed: RIT_2014_155.inkml
# Processed: 517_em_408.inkml
# Processed: 37_em_24.inkml
# Processed: 515_em_358.inkml
# Processed: RIT_2014_71.inkml
# Processed: 516_em_386.inkml
# Processed: 23_em_50.inkml
# Processed: RIT_2014_135.inkml
# Processed: 27_em_110.inkml
# Processed: 516_em_382.inkml
# Processed: RIT_2014_270.inkml
# Processed: 514_em_345.inkml
# Processed: 501_em_11.inkml
# Processed: RIT_2014_257.inkml
# Processed: 511_em_253.inkml
# Processed: RIT_2014_213.inkml
# Processed: RIT_2014_77.inkml
# Processed: 501_em_13.inkml
# Processed: 501_em_14.inkml
# Processed: 511_em_258.inkml
# Processed: 512_em_287.inkml
# Processed: 20_em_47.inkml
# Processed: RIT_2014_81.inkml
# Processed: 515_em_368.inkml
# Processed: RIT_2014_75.inkml
# Processed: RIT_2014_233.inkml
# Processed: RIT_2014_204.inkml
# Processed: RIT_2014_38.inkml
# Processed: 36_em_38.inkml
# Processed: 32_em_224.inkml
# Processed: 506_em_67.inkml
# Processed: RIT_2014_88.inkml
# Processed: 27_em_103.inkml
# Processed: 508_em_88.inkml
# Processed: 507_em_74.inkml
# Processed: 519_em_448.inkml
# Processed: RIT_2014_34.inkml
# Processed: 514_em_333.inkml
# Processed: 505_em_55.inkml
# Processed: 26_em_98.inkml
# Processed: RIT_2014_110.inkml
# Processed: 37_em_32.inkml
# Processed: 503_em_33.inkml
# Processed: RIT_2014_199.inkml
# Processed: 514_em_332.inkml
# Processed: 510_em_103.inkml
# Processed: RIT_2014_20.inkml
# Processed: RIT_2014_234.inkml
# Processed: RIT_2014_39.inkml
# Processed: 518_em_415.inkml
# Processed: 513_em_303.inkml
# Processed: 29_em_172.inkml
# Processed: RIT_2014_23.inkml
# Processed: 518_em_435.inkml
# Processed: 23_em_62.inkml
# Processed: 36_em_48.inkml
# Processed: 29_em_157.inkml
# Processed: 28_em_128.inkml
# Processed: RIT_2014_10.inkml
# Processed: 26_em_80.inkml
# Processed: RIT_2014_29.inkml
# Processed: RIT_2014_133.inkml
# Processed: 512_em_282.inkml
# Processed: 26_em_85.inkml
# Processed: RIT_2014_70.inkml
# Processed: 20_em_43.inkml
# Processed: 502_em_19.inkml
# Processed: RIT_2014_153.inkml
# Processed: RIT_2014_60.inkml
# Processed: 518_em_419.inkml
# Processed: RIT_2014_274.inkml
# Processed: 34_em_235.inkml
# Processed: 18_em_9.inkml
# Processed: RIT_2014_13.inkml
# Processed: 513_em_311.inkml
# Processed: 32_em_222.inkml
# Processed: 516_em_377.inkml
# Processed: 31_em_198.inkml
# Processed: 29_em_164.inkml
# Processed: 517_em_405.inkml
# Processed: 37_em_13.inkml
# Processed: RIT_2014_224.inkml
# Processed: 508_em_86.inkml
# Processed: 18_em_17.inkml
# Processed: 512_em_299.inkml
# Processed: 501_em_4.inkml
# Processed: 35_em_4.inkml
# Processed: 510_em_101.inkml
# Processed: 26_em_89.inkml
# Processed: 519_em_440.inkml
# Processed: 516_em_379.inkml
# Processed: 509_em_92.inkml
# Processed: 32_em_203.inkml
# Processed: 29_em_162.inkml
# Processed: 505_em_49.inkml
# Processed: RIT_2014_237.inkml
# Processed: 37_em_1.inkml
# Processed: RIT_2014_72.inkml
# Processed: 512_em_294.inkml
# Processed: 36_em_28.inkml
# Processed: RIT_2014_147.inkml
# Processed: 513_em_310.inkml
# Processed: RIT_2014_220.inkml
# Processed: RIT_2014_256.inkml
# Processed: RIT_2014_76.inkml
# Processed: RIT_2014_6.inkml
# Processed: 36_em_37.inkml
# Processed: RIT_2014_31.inkml
# Processed: RIT_2014_301.inkml
# Processed: 36_em_47.inkml
# Processed: RIT_2014_264.inkml
# Processed: 505_em_56.inkml
# Processed: 501_em_3.inkml
# Processed: 27_em_122.inkml
# Processed: RIT_2014_104.inkml
# Processed: 36_em_46.inkml
# Processed: 37_em_18.inkml
# Processed: 511_em_270.inkml
# Processed: 34_em_240.inkml
# Processed: 36_em_33.inkml
# Processed: 511_em_274.inkml
# Processed: RIT_2014_285.inkml
# Processed: 513_em_302.inkml
# Processed: 31_em_199.inkml
# Processed: 35_em_0.inkml
# Processed: RIT_2014_56.inkml
# Processed: 18_em_19.inkml
# Processed: RIT_2014_193.inkml
# Processed: 36_em_25.inkml
# Processed: RIT_2014_144.inkml
# Processed: RIT_2014_238.inkml
# Processed: 501_em_10.inkml
# Processed: 514_em_343.inkml
# Processed: 502_em_7.inkml
# Processed: RIT_2014_158.inkml
# Processed: 29_em_155.inkml
# Processed: RIT_2014_40.inkml
# Processed: 508_em_85.inkml
# Processed: RIT_2014_1.inkml
# Processed: 503_em_26.inkml
# Processed: RIT_2014_117.inkml
# Processed: 37_em_10.inkml
# Processed: 37_em_27.inkml
# Processed: 31_em_176.inkml
# Processed: 515_em_367.inkml
# Processed: 35_em_15.inkml
# Processed: 513_em_314.inkml
# Processed: 511_em_272.inkml
# Processed: RIT_2014_125.inkml
# Processed: 37_em_25.inkml
# Processed: 26_em_87.inkml
# Processed: 515_em_360.inkml
# Processed: 37_em_5.inkml
# Processed: 511_em_254.inkml
# Processed: 31_em_188.inkml
# Processed: 516_em_384.inkml
# Processed: 23_em_72.inkml
# Processed: RIT_2014_159.inkml
# Processed: 502_em_8.inkml
# Processed: RIT_2014_44.inkml
# Processed: RIT_2014_79.inkml
# Processed: 32_em_204.inkml
# Processed: 501_em_21.inkml
# Processed: 519_em_460.inkml
# Processed: 511_em_255.inkml
# Processed: 508_em_84.inkml
# Processed: 23_em_65.inkml
# Processed: 34_em_229.inkml
# Processed: 501_em_5.inkml
# Processed: RIT_2014_226.inkml
# Processed: 36_em_34.inkml
# Processed: 505_em_53.inkml
# Processed: 519_em_457.inkml
# Processed: 511_em_256.inkml
# Processed: RIT_2014_137.inkml
# Processed: 23_em_71.inkml
# Processed: 501_em_19.inkml
# Processed: 28_em_126.inkml
# Processed: RIT_2014_112.inkml
# Processed: 27_em_123.inkml
# Processed: 501_em_24.inkml
# Processed: RIT_2014_253.inkml
# Processed: RIT_2014_160.inkml
# Processed: 513_em_306.inkml
# Processed: 516_em_388.inkml
# Processed: 503_em_25.inkml
# Processed: 23_em_59.inkml
# Processed: 512_em_295.inkml
# Processed: 28_em_133.inkml
# Processed: 36_em_39.inkml
# Processed: 23_em_67.inkml
# Processed: 34_em_249.inkml
# Processed: 501_em_2.inkml
# Processed: RIT_2014_165.inkml
# Processed: 515_em_362.inkml
# Processed: 31_em_194.inkml
# Processed: 502_em_3.inkml
# Processed: 503_em_32.inkml
# Processed: 37_em_16.inkml
# Processed: RIT_2014_277.inkml
# Processed: RIT_2014_146.inkml
# Processed: RIT_2014_216.inkml
# Processed: 508_em_81.inkml
# Processed: RIT_2014_100.inkml
# Processed: 35_em_11.inkml
# Processed: RIT_2014_142.inkml
# Processed: 18_em_16.inkml
# Processed: 506_em_61.inkml
# Processed: 23_em_53.inkml
# Processed: 512_em_283.inkml
# Processed: 35_em_7.inkml
# Processed: 511_em_259.inkml
# Processed: RIT_2014_269.inkml
# Processed: RIT_2014_309.inkml
# Processed: RIT_2014_123.inkml
# Processed: 520_em_465.inkml
# Processed: 28_em_130.inkml
# Processed: 27_em_105.inkml
# Processed: 511_em_257.inkml
# Processed: 514_em_341.inkml
# Processed: 519_em_447.inkml
# Processed: 516_em_376.inkml
# Processed: 28_em_144.inkml
# Processed: 520_em_466.inkml
# Processed: 20_em_41.inkml
# Processed: RIT_2014_49.inkml
# Processed: RIT_2014_14.inkml
# Processed: 20_em_32.inkml
# Processed: 18_em_21.inkml
# Processed: RIT_2014_217.inkml
# Processed: RIT_2014_195.inkml
# Processed: 511_em_271.inkml
# Processed: 515_em_373.inkml
# Processed: 26_em_79.inkml
# Processed: RIT_2014_218.inkml
# Processed: RIT_2014_282.inkml
# Processed: RIT_2014_50.inkml
# Processed: 20_em_37.inkml
# Processed: RIT_2014_90.inkml
# Processed: 29_em_160.inkml
# Processed: RIT_2014_275.inkml
# Processed: 502_em_18.inkml
# Processed: RIT_2014_9.inkml
# Processed: RIT_2014_5.inkml
# Processed: 504_em_44.inkml
# Processed: 513_em_324.inkml
# Processed: RIT_2014_273.inkml
# Processed: RIT_2014_231.inkml
# Processed: 506_em_66.inkml
# Processed: RIT_2014_43.inkml
# Processed: 506_em_64.inkml
# Processed: RIT_2014_3.inkml
# Processed: 518_em_431.inkml
# Processed: 504_em_38.inkml
# Processed: RIT_2014_179.inkml
# Processed: 515_em_357.inkml
# Processed: RIT_2014_51.inkml
# Processed: 509_em_96.inkml
# Processed: 512_em_284.inkml
# Processed: RIT_2014_210.inkml
# Processed: RIT_2014_169.inkml
# Processed: 504_em_43.inkml
# Processed: 504_em_45.inkml
# Processed: RIT_2014_59.inkml
# Processed: RIT_2014_223.inkml
# Processed: RIT_2014_296.inkml
# Processed: 518_em_427.inkml
# Processed: RIT_2014_290.inkml
# Processed: 512_em_279.inkml
# Processed: 28_em_140.inkml
# Processed: 31_em_175.inkml
# Processed: 513_em_304.inkml
# Processed: RIT_2014_278.inkml
# Processed: 29_em_150.inkml
# Processed: 18_em_2.inkml
# Processed: 512_em_286.inkml
# Processed: 502_em_9.inkml
# Processed: RIT_2014_30.inkml
# Processed: RIT_2014_289.inkml
# Processed: 27_em_114.inkml
# Processed: RIT_2014_122.inkml
# Processed: 506_em_57.inkml
# Processed: 506_em_62.inkml
# Processed: RIT_2014_312.inkml
# Processed: RIT_2014_305.inkml
# Processed: 504_em_40.inkml
# Processed: 517_em_412.inkml
# Processed: 36_em_44.inkml
# Processed: 26_em_78.inkml
# Processed: 511_em_266.inkml
# Processed: 37_em_7.inkml
# Processed: 514_em_325.inkml
# Processed: 18_em_1.inkml
# Processed: 511_em_260.inkml
# Processed: 512_em_278.inkml
# Processed: RIT_2014_92.inkml
# Processed: 516_em_398.inkml
# Processed: RIT_2014_184.inkml
# Processed: 31_em_181.inkml
# Processed: 518_em_420.inkml
# Processed: 29_em_170.inkml
# Processed: RIT_2014_45.inkml
# Processed: 501_em_0.inkml
# Processed: RIT_2014_154.inkml
# Processed: 32_em_223.inkml
# Processed: 20_em_27.inkml
# Processed: 35_em_3.inkml
# Processed: RIT_2014_11.inkml
# Processed: RIT_2014_174.inkml
# Processed: 35_em_24.inkml
# Processed: 27_em_120.inkml
# Processed: 32_em_219.inkml
# Processed: 519_em_462.inkml
# Processed: 513_em_320.inkml
# Processed: RIT_2014_201.inkml
# Processed: RIT_2014_67.inkml
# Processed: 511_em_250.inkml
# Processed: RIT_2014_48.inkml
# Processed: 500_em_109.inkml
# Processed: 35_em_18.inkml
# Processed: 26_em_75.inkml
# Processed: 23_em_55.inkml
# Processed: 20_em_31.inkml
# Processed: RIT_2014_27.inkml
# Processed: 513_em_317.inkml
# Processed: 518_em_426.inkml
# Processed: 515_em_352.inkml
# Processed: RIT_2014_15.inkml
# Processed: 502_em_5.inkml
# Processed: 502_em_10.inkml
# Processed: RIT_2014_97.inkml
# Processed: 35_em_9.inkml
# Processed: RIT_2014_284.inkml
# Processed: 37_em_4.inkml
# Processed: RIT_2014_252.inkml
# Processed: 514_em_344.inkml
# Processed: 516_em_389.inkml
# Processed: 518_em_414.inkml
# Processed: RIT_2014_86.inkml
# Processed: RIT_2014_64.inkml
# Processed: 28_em_146.inkml
# Processed: 27_em_119.inkml
# Processed: 23_em_63.inkml
# Processed: RIT_2014_182.inkml
# Processed: 518_em_428.inkml
# Processed: 503_em_27.inkml
# Processed: RIT_2014_181.inkml
# Processed: RIT_2014_188.inkml
# Processed: RIT_2014_262.inkml
# Processed: RIT_2014_95.inkml
# Processed: 512_em_277.inkml
# Processed: 28_em_139.inkml
# Processed: RIT_2014_28.inkml
# Processed: 501_em_12.inkml
# Processed: RIT_2014_214.inkml
# Processed: 513_em_305.inkml
# Processed: 32_em_220a.inkml
# Processed: RIT_2014_183.inkml
# Processed: 36_em_30.inkml
# Processed: RIT_2014_197.inkml
# Processed: RIT_2014_102.inkml
# Processed: 502_em_21.inkml
# Processed: RIT_2014_243.inkml
# Processed: 28_em_135.inkml
# Processed: RIT_2014_190.inkml
# Processed: 515_em_364.inkml
# Processed: 507_em_77.inkml
# Processed: RIT_2014_276.inkml
# Processed: 34_em_238.inkml
# Processed: 502_em_1.inkml
# Processed: 514_em_338.inkml
# Processed: 31_em_195.inkml
# Processed: 518_em_436.inkml
# Processed: RIT_2014_149.inkml
# Processed: RIT_2014_129.inkml
# Processed: 519_em_441.inkml
# Processed: RIT_2014_132.inkml
# Processed: RIT_2014_302.inkml
# Processed: RIT_2014_17.inkml
# Processed: 512_em_290.inkml
# Processed: RIT_2014_293.inkml
# Processed: RIT_2014_115.inkml
# Processed: 500_em_110.inkml
# Processed: RIT_2014_196.inkml
# Processed: 507_em_71.inkml
# Processed: 35_em_17.inkml
# Processed: RIT_2014_103.inkml
# Processed: 515_em_365.inkml
# Processed: 34_em_246.inkml
# Processed: RIT_2014_141.inkml
# Processed: RIT_2014_230.inkml
# Processed: 27_em_112.inkml
# Processed: RIT_2014_207.inkml
# Processed: 20_em_48.inkml
# Processed: 28_em_137.inkml
# Processed: 28_em_138.inkml
# Processed: RIT_2014_203.inkml
# Processed: 35_em_23.inkml
# Processed: 18_em_7.inkml
# Processed: 501_em_15.inkml
# Processed: RIT_2014_281.inkml
# Processed: 502_em_12.inkml
# Processed: 37_em_17.inkml
# Processed: RIT_2014_121.inkml
# Processed: 504_em_36.inkml
# Processed: RIT_2014_53.inkml
# Processed: 504_em_41.inkml
# Processed: 518_em_432.inkml
# Processed: RIT_2014_239.inkml
# Processed: RIT_2014_308.inkml
# Processed: 513_em_319.inkml
# Processed: 18_em_15.inkml
# Processed: 518_em_417.inkml
# Processed: 20_em_25.inkml
# Processed: 510_em_107.inkml
# Processed: RIT_2014_46.inkml
# Processed: 32_em_202.inkml
# Processed: RIT_2014_57.inkml
# Processed: RIT_2014_61.inkml
# Processed: RIT_2014_304.inkml
# Processed: 515_em_354.inkml
# Processed: 32_em_208.inkml
# Processed: 37_em_23.inkml
# Processed: RIT_2014_306.inkml
# Processed: RIT_2014_246.inkml
# Processed: RIT_2014_108.inkml
# Processed: 511_em_269.inkml
# Processed: RIT_2014_32.inkml
# Processed: 20_em_45.inkml
# Processed: RIT_2014_126.inkml
# Processed: 513_em_313.inkml
# Processed: 501_em_7.inkml
# Processed: 37_em_31.inkml
# Processed: 518_em_421.inkml
# Processed: 519_em_454.inkml
# Processed: RIT_2014_250.inkml
# Processed: 32_em_209.inkml
# Processed: RIT_2014_209.inkml
# Processed: 18_em_10.inkml
# Processed: RIT_2014_130.inkml
# Processed: 516_em_393.inkml
# Processed: 516_em_399.inkml
# Processed: 512_em_292.inkml
# Processed: 512_em_291.inkml
# Processed: 23_em_57.inkml
# Processed: 517_em_401.inkml
# Processed: 28_em_129.inkml
# Processed: 34_em_234.inkml
# Processed: 36_em_26.inkml
# Processed: 32_em_206.inkml
# Processed: RIT_2014_211.inkml
# Processed: 501_em_9.inkml
# Processed: 515_em_372.inkml
# Processed: RIT_2014_189.inkml
# Processed: 506_em_63.inkml
# Processed: 29_em_156.inkml
# Processed: RIT_2014_101.inkml
# Processed: 513_em_323.inkml
# Processed: 31_em_191.inkml
# Processed: 513_em_307.inkml
# Processed: 29_em_161.inkml
# Processed: 18_em_6.inkml
# Processed: RIT_2014_80.inkml
# Processed: 516_em_385.inkml
# Processed: 28_em_145.inkml
# Processed: 27_em_113.inkml
# Processed: 518_em_438.inkml
# Processed: 503_em_28.inkml
# Processed: 27_em_111.inkml
# Processed: 28_em_136.inkml
# Processed: 20_em_39.inkml
# Processed: 18_em_24.inkml
# Processed: RIT_2014_287.inkml
# Processed: RIT_2014_22.inkml
# Processed: 518_em_437.inkml
# Processed: 515_em_363.inkml
# Processed: 506_em_60.inkml
# Processed: 18_em_22.inkml
# Processed: RIT_2014_152.inkml
# Processed: 517_em_404.inkml
# Processed: 31_em_180.inkml
# Processed: 518_em_430.inkml
# Processed: 27_em_116.inkml
# Processed: 504_em_35.inkml
# Processed: 514_em_327.inkml
# Processed: 511_em_264.inkml
# Processed: 519_em_461.inkml
# Processed: 27_em_117.inkml
# Processed: 32_em_216.inkml
# Processed: 34_em_227.inkml
# Processed: RIT_2014_25.inkml
# Processed: 36_em_31.inkml
# Processed: 515_em_374.inkml
# Processed: RIT_2014_24.inkml
# Processed: 506_em_58.inkml
# Processed: 36_em_35.inkml
# Processed: 516_em_387.inkml
# Processed: 502_em_23.inkml
# Processed: RIT_2014_225.inkml
# Processed: 23_em_52.inkml
# Processed: 511_em_273.inkml
# Processed: 29_em_166.inkml
# Processed: 29_em_153.inkml
# Processed: RIT_2014_227.inkml
# Processed: 20_em_49.inkml
# Processed: 517_em_403.inkml
# Processed: 31_em_182.inkml
# Processed: RIT_2014_251.inkml
# Processed: 34_em_232.inkml
# Processed: 26_em_82.inkml
# Processed: 32_em_220b.inkml
# Processed: RIT_2014_267.inkml
# Processed: 508_em_87.inkml
# Processed: 18_em_0.inkml
# Processed: 32_em_214.inkml
# Processed: 514_em_334.inkml
# Processed: 32_em_220c.inkml
# Processed: 29_em_173.inkml
# Processed: 508_em_78.inkml
# Processed: RIT_2014_236.inkml
# Processed: RIT_2014_268.inkml
# Processed: 26_em_92.inkml
# Processed: 516_em_392.inkml
# Processed: 509_em_97.inkml
# Processed: 34_em_243.inkml
# Processed: RIT_2014_205.inkml
# Processed: 502_em_22.inkml
# Processed: 513_em_318.inkml
# Processed: RIT_2014_63.inkml
# Processed: 502_em_17.inkml
# Processed: 503_em_29.inkml
# Processed: 508_em_80.inkml
# Processed: 513_em_308.inkml
# Processed: RIT_2014_175.inkml
# Processed: 504_em_39.inkml
# Processed: 27_em_121.inkml
# Processed: RIT_2014_145.inkml
# Processed: 27_em_104.inkml
# Processed: 512_em_281.inkml
# Processed: 513_em_316.inkml
# Processed: 514_em_342.inkml
# Processed: RIT_2014_271.inkml
# Processed: RIT_2014_8.inkml
# Processed: 518_em_425.inkml
# Processed: 36_em_32.inkml
# Processed: RIT_2014_176.inkml
# Processed: RIT_2014_16.inkml
# Processed: 502_em_0.inkml
# Processed: 27_em_118.inkml
# Processed: 32_em_211.inkml
# Processed: 509_em_98.inkml
# Processed: RIT_2014_300.inkml
# Processed: 29_em_163.inkml
# Processed: 513_em_309.inkml
#
# ✅ Done! Processed images saved in: results_valid/processed_images

# %%
# Tokenizing (inspired from https://www.kaggle.com/code/hayamonawwar/crohme-ctc-pytorch-cur/edit)
input_files = ['/kaggle/input/crohme2019/crohme2019_train.txt']
#'/kaggle/input/crohme2019/crohme2019_valid.txt',
#'/kaggle/input/crohme2019/crohme2019_test.txt']

vocab = set()

for input_file in input_files:
    for line in open(input_file).readlines():
        if len(line.strip().split('\t')) == 2:
            vocab.update(line.strip().split('\t')[1].split())
vocab_syms = [v for v in vocab if v not in ['Above', 'Below', 'Inside', 'NoRel', 'Right', 'Sub', 'Sup']]

with open('train_vocab.txt', 'w') as f:
    f.writelines([c + '\n' for c in sorted(vocab_syms)])
    f.writelines([c + '\n' for c in ['Above', 'Below', 'Inside', 'NoRel', 'Right', 'Sub', 'Sup']])

class Vocab(object):
    def __init__(self, vocab_file=None):
        self.word2index = {}
        self.index2word = {}

        if vocab_file:
            self.load_vocab(vocab_file)
    
    def load_vocab(self, vocab_file):
        # load vocab from file
        with open(vocab_file, 'r') as f:
            for i, line in enumerate(f):
                word = line.strip()
                self.word2index[word] = i
                self.index2word[i] = word
        # add blank word
        self.word2index['<blank>'] = len(self.word2index)
        self.index2word[self.word2index['<blank>']] = '<blank>'
#vocab = Vocab(vocab_file = '/kaggle/working/results_train/train_vocab.txt')
#vocab.index2word

# %%
# Testing
vocab = Vocab('train_vocab.txt')
input = '- Right \\sqrt Inside 2'.split()
output = [vocab.word2index[word] for word in input]
output # Should be [4, 105, 66, 103, 9]
# Out:
# [4, 105, 66, 103, 9]

# %%
# Custom dataset
from torch.utils.data import Dataset
from PIL import Image
import os
import torch
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim

class Vocab(object):
    def __init__(self, vocab_file):
        self.word2index = {}
        self.index2word = {}
        with open(vocab_file, 'r') as f:
            for i, line in enumerate(f):
                word = line.strip()
                self.word2index[word] = i
                self.index2word[i] = word
        self.word2index['<blank>'] = len(self.word2index)
        self.index2word[self.word2index['<blank>']] = '<blank>'

# Custom Dataset Class

class CROHMEDataset(Dataset):
    def __init__(self, img_dir, label_file, vocab, transform=None):
        self.img_dir = img_dir
        self.transform = transform
        self.vocab = vocab
        self.samples = []

        with open(label_file, 'r', encoding='utf-8') as f:
            for line in f:
                parts = line.strip().split('\t')
                if len(parts) != 2:
                    print(f"⚠️ Skipping malformed line: {line.strip()}")
                    # Attempt to delete corresponding image if found
                    if parts and parts[0].endswith('.png'):
                        image_path = os.path.join(self.img_dir, parts[0])
                        if os.path.exists(image_path):
                            os.remove(image_path)
                            print(f"🗑️ Deleted image: {image_path}")
                    continue

                img_name, label = parts
                self.samples.append((img_name, label))
    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_name, label = self.samples[idx]
    
        # Fix for .inkml extensions and subdirectories
        img_name = os.path.basename(img_name)  # Remove subdirectory like 'crohme2019/train/...'
        img_name = os.path.splitext(img_name)[0] + '.png'  # Ensure it's .png
    
        img_path = os.path.join(self.img_dir, img_name)
        if not os.path.exists(img_path):
            raise FileNotFoundError(f"Image not found: {img_path}")
    
        image = Image.open(img_path).convert("RGB")
    
        if self.transform:
            image = self.transform(image)
    
        label_indices = [self.vocab.word2index[word] for word in label.split()]
        return image, torch.tensor(label_indices, dtype=torch.long)
    
def collate_fn(batch):
    images, labels = zip(*batch)
    image_tensors = torch.stack(images)
    label_lengths = [len(label) for label in labels]
    padded_labels = nn.utils.rnn.pad_sequence(labels, batch_first=True, padding_value=0)
    return image_tensors, padded_labels, label_lengths

# %%
from torch.utils.data import DataLoader
from torchvision import transforms

# Image transform
transform = transforms.Compose([
    transforms.Resize((100, 100)),
    transforms.RandomRotation(degrees=2),
    transforms.ColorJitter(brightness=0.1, contrast=0.1),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])


# Load vocab files
train_vocab = Vocab('/kaggle/working/train_vocab.txt')
test_vocab = Vocab('/kaggle/working/test_vocab.txt')
valid_vocab  = Vocab('/kaggle/working/valid_vocab.txt')

# Dataset paths
train_img_dir = '/kaggle/working/results_train/processed_images'
valid_img_dir = '/kaggle/working/results_valid/processed_images'
test_img_dir  = '/kaggle/working/results_test/processed_images'

train_labels = '/kaggle/input/crohme2019/crohme2019_train.txt'
valid_labels = '/kaggle/input/crohme2019/crohme2019_valid.txt'
test_labels  = '/kaggle/input/crohme2019/crohme2019_test.txt'

# Datasets
train_set = CROHMEDataset(train_img_dir, train_labels, train_vocab, transform)
valid_set = CROHMEDataset(valid_img_dir, valid_labels, valid_vocab, transform)
test_set  = CROHMEDataset(test_img_dir, test_labels, test_vocab, transform)

# DataLoaders
train_loader = DataLoader(train_set, batch_size=16, shuffle=True, collate_fn=collate_fn)
valid_loader = DataLoader(valid_set, batch_size=16, shuffle=False, collate_fn=collate_fn)
test_loader  = DataLoader(test_set, batch_size=16, shuffle=False, collate_fn=collate_fn)

# Set vocab for training loop
vocab = train_vocab
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-05647eb53423> in <cell line: 16>()
#      14 # Load vocab files
#      15 train_vocab = Vocab('/kaggle/working/train_vocab.txt')
# ---> 16 test_vocab = Vocab('/kaggle/working/test_vocab.txt')
#      17 valid_vocab  = Vocab('/kaggle/working/valid_vocab.txt')
#      18
#
# <ipython-input-4-15b83f83d2e4> in __init__(self, vocab_file)
#      12         self.word2index = {}
#      13         self.index2word = {}
# ---> 14         with open(vocab_file, 'r') as f:
#      15             for i, line in enumerate(f):
#      16                 word = line.strip()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/test_vocab.txt'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score


# Function to compute Levenshtein Distance (used for WER and CER)
def levenshtein_distance(a, b):
    m = len(a) + 1
    n = len(b) + 1
    dp = np.zeros((m, n))
    
    for i in range(m):
        dp[i][0] = i
    for j in range(n):
        dp[0][j] = j
    
    for i in range(1, m):
        for j in range(1, n):
            cost = 0 if a[i - 1] == b[j - 1] else 1
            dp[i][j] = min(dp[i - 1][j] + 1, dp[i][j - 1] + 1, dp[i - 1][j - 1] + cost)
    
    return dp[m - 1][n - 1]


# Function to calculate Word Error Rate (WER)
def compute_wer(predictions, labels):
    total_words = sum(len(label.split()) for label in labels)
    errors = 0
    for pred, label in zip(predictions, labels):
        errors += levenshtein_distance(pred.split(), label.split())  # Calculate WER at word level
    return errors / total_words if total_words > 0 else 0


# Function to calculate Character Error Rate (CER)
def compute_cer(predictions, labels):
    total_chars = sum(len(label) for label in labels)
    errors = 0
    for pred, label in zip(predictions, labels):
        errors += levenshtein_distance(list(pred), list(label))  # Calculate CER at character level
    return errors / total_chars if total_chars > 0 else 0


# Model Definition (CRNN class)
class CRNN(nn.Module):
    def __init__(self, num_classes):
        super(CRNN, self).__init__()
        resnet = models.resnet18(pretrained=False)
        state_dict = torch.load("/kaggle/input/resnet18/resnet18-f37072fd.pth")
        resnet.load_state_dict(state_dict)

        # Freeze first few layers to avoid overfitting
        for param in list(resnet.children())[:5]:
            for p in param.parameters():
                p.requires_grad = False

        # Extract CNN layers up to layer3
        self.cnn = nn.Sequential(
            *list(resnet.children())[:-3],                # Keep until layer3
            nn.BatchNorm2d(256),                          # Add BatchNorm after last conv layer
            nn.Dropout2d(p=0.3)                           # Dropout after batchnorm
        )

        # Bidirectional LSTM with dropout
        self.rnn = nn.LSTM(
            input_size=256,
            hidden_size=256,
            num_layers=2,
            dropout=0.5,              # Dropout between LSTM layers
            bidirectional=True,
            batch_first=True
        )

        self.dropout_fc = nn.Dropout(p=0.3)              # Dropout before final classification
        self.fc = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.cnn(x)  # (B, 256, H, W)
        x = nn.functional.adaptive_avg_pool2d(x, (1, x.size(3)))  # (B, 256, 1, W)
        x = x.squeeze(2)  # (B, 256, W)
        x = x.permute(0, 2, 1)  # (B, W, 256)
        x, _ = self.rnn(x)
        x = self.fc(x)
        return x


# Training Code
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = CRNN(num_classes=len(vocab.word2index)).to(device)
criterion = nn.CTCLoss(blank=vocab.word2index['<blank>'], zero_infinity=True)
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# Add this:
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',         # Minimize the validation loss
    factor=0.5,         # Reduce LR by a factor of 0.5
    patience=2,         # Wait for 2 epochs before reducing LR
    verbose=True        # Print LR updates
)


train_losses = []
val_losses = []
train_wer = []
val_wer = []
train_cer = []
val_cer = []

def decode(output, vocab):
    preds = output.argmax(dim=-1)  # (B, T)
    decoded = []
    for pred in preds:
        tokens = []
        prev = -1
        for p in pred:
            if p != prev and p != vocab.word2index['<blank>']:
                tokens.append(vocab.index2word[p.item()])
            prev = p
        decoded.append(" ".join(tokens))
    return decoded
    
num_epochs = 35

for epoch in range(num_epochs):
    model.train()
    epoch_train_loss = 0
    epoch_train_preds = []
    epoch_train_labels = []

    for images, labels, label_lengths in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        label_lengths = torch.tensor(label_lengths, dtype=torch.long)

        output = model(images)
        output = output.permute(1, 0, 2)
        input_lengths = torch.full(size=(output.size(1),), fill_value=output.size(0), dtype=torch.long)

        loss = criterion(output, labels, input_lengths, label_lengths)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_train_loss += loss.item()

        # Decode predictions and accumulate for WER/CER calculation
        preds = decode(output, vocab)
        labels_decoded = []
        for lbl in labels:
            tokens = [vocab.index2word[l.item()] for l in lbl if l.item() != vocab.word2index['<blank>']]
            labels_decoded.append(" ".join(tokens))
        epoch_train_preds.extend(preds)
        epoch_train_labels.extend(labels_decoded)

    avg_train_loss = epoch_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)

    # Compute Train WER and CER
    train_wer.append(compute_wer(epoch_train_preds, epoch_train_labels))
    train_cer.append(compute_cer(epoch_train_preds, epoch_train_labels))

    # Validation
    model.eval()
    epoch_val_loss = 0
    epoch_val_preds = []
    epoch_val_labels = []

    with torch.no_grad():
        for images, labels, label_lengths in valid_loader:
            images = images.to(device)
            labels = labels.to(device)
            label_lengths = torch.tensor(label_lengths, dtype=torch.long)

            output = model(images)
            output = output.permute(1, 0, 2)
            input_lengths = torch.full(size=(output.size(1),), fill_value=output.size(0), dtype=torch.long)

            val_loss = criterion(output, labels, input_lengths, label_lengths)
            epoch_val_loss += val_loss.item()

            # Decode predictions and accumulate for WER/CER calculation
            preds = decode(output, vocab)
            labels_decoded = [vocab.index2word[label.item()] for label in labels[0]]
            epoch_val_preds.extend(preds)
            epoch_val_labels.extend(labels_decoded)

    avg_val_loss = epoch_val_loss / len(valid_loader)
    val_losses.append(avg_val_loss)
    scheduler.step(avg_val_loss)

    # Compute Validation WER and CER
    val_wer.append(compute_wer(epoch_val_preds, epoch_val_labels))
    val_cer.append(compute_cer(epoch_val_preds, epoch_val_labels))

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}, Train WER: {train_wer[-1]:.4f}, Val WER: {val_wer[-1]:.4f}")

# Plotting Loss and Accuracy Metrics
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss', marker='o')
plt.plot(val_losses, label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('CTC Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_wer, label='Train WER', marker='o')
plt.plot(val_wer, label='Validation WER', marker='o')
plt.xlabel('Epoch')
plt.ylabel('WER')
plt.title('Train vs Validation WER')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
